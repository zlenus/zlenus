# %% [markdown]
# # Final Project
# My final project is a story quest game. The player gets to anser a riddle and faces an obstacle to see if they are worthy enough to each the end. A simple fictional game that tests your choices and sees if you can make the right decision.

# %%
class Name():
    name = ''
    def getName():
        return input("What is your name?")

# %%
class Character():
    health = 20
    character = ''
    
    """pick your character """   
    def chooseCharacter(self):
        num= input("Choose your character.\n \
                    1 --->   ʕ•ᴥ•ʔ \n \
                    2 --->  (๑•̀ㅂ•́)ﻭ✧\n \
                    3 --->  (▀̿̿Ĺ̯̿▀̿ ̿) \n \
                    4 --->  ( ͡° ͜ʖ ͡°) ")
        if num == '1':
            self.character= 'ʕ•ᴥ•ʔ'
            return 'ʕ•ᴥ•ʔ'
        elif num == '2':
            self.character= '(๑•̀ㅂ•́)ﻭ✧'
            return '(๑•̀ㅂ•́)ﻭ✧'
        elif num == '3':
            self.character='(▀̿̿Ĺ̯̿▀̿ ̿) '
            return '(▀̿̿Ĺ̯̿▀̿ ̿) '
        elif num == '4':
            self.character= '( ͡° ͜ʖ ͡°)'
            return '( ͡° ͜ʖ ͡°)'
        else:
            self.character = 'ಠ_ಠ'
            return 'You had options and yet you didn\'t pick one so now you\'re this ಠ_ಠ'
        
    """formal representation of health status"""    
    def vitals(self):
        return "Your health level is at "+ str(self.health)
    
    """just health value"""
    def energy(self):
        return self.health
    
    """lowering of health (if wrong option is chosen)"""
    def hurt(self):
        self.health = self.health - 10
        
    def haveInjury(self):
        return "Your health level has been lowered to "+ str(self.health)
        
    """ first riddle told by pig"""    
    def riddle(self):
        solution = input("*PIG*: STOP, YOU MUST ANSWER MY RIDDLE TO CROSS THIS BRIDGE: \n \
                          This is a type of animal\n \
                          Which has a curly tail\n \
                          A female is called a sow\n \
                          And a boar is the male\n")
        if solution == 'pig' or solution == 'Pig':
            input("Dang that's pretty concided for a pig to make themself the answer\n \
                    but anyway congrats let's continue")
        else:
            self.hurt()
            input("whoops you got out smarted by a pig...\n \
                  but I'll let you pass, I'll just take off some health points" )
    
    """decision to fight or talk with the night"""
    def choices(self):
        response = input("What do you want to do fight or talk")
        if response == 'fight' or response == 'Fight':
            self.hurt()
            input("You really tried to fight A KNIGHT??? He has STEEL ARMOUR!\n \
                   Are you crazy?!? You definetely got hurt")
        else:
            input("Wow turns out the knight just wanted a friend to talk too. Congrats he let you through!")

# %%
def chat():
    
    """new object of character class"""
    player = Character()
    
    """Begining of game"""
    input('Welcome to the adventure! Press enter to move forward in the story.')
    
    """Name of player"""
    input('Welcome to your story '+ Name.getName()+"!")

    """Checks if player is ready"""
    answer = input ("Are you ready?")
    if answer == 'yes' or answer =='Yes':
        good =True
        input( "Good Luck Traveler, your quest is about to begin")

        if good:
            print("Let's set the basics")
            input("You have picked --->"+ player.chooseCharacter())
            input("Let's see how your character is doing. "+ player.vitals())
            input("Okay you seem fine......for now \n \
                  Winning this game is quite simple \n \
                  You must answer a riddle but it may not always be easy")
            
            """first opponent""" #Professor Ellis said it's fine for my image code lines to be greater than 79 character
            input("Picture this you're walking when you stumble upon a bridge")
            print("         |  |             | |\n         |  |-------------| |\n         |  |             | |\n         |  |             | |\n============|===============|===-- \n~~~~~~~~~|  |~~~~~~~~~~~~~| |~~~~~~   ")
            input('Oh look at that, it\'s a pig near the bridge')
            print("    _____\n ^..^     \9\n (oo)_____/\n    WW  WW")
            
            player.riddle()
            
            """health status shown"""
            input("\nLet's see how your character is doing. "+ player.vitals())
            
            """ Second opponent""" #Professor Ellis said it's fine for my image code lines to be greater than 79 character
            print("                             -|             |-\n         -|                  [-_-_-_-_-_-_-_-]                  |-\n         [-_-_-_-_-]          |             |          [-_-_-_-_-]\n          | o   o |           [  0   0   0  ]           | o   o |\n           |     |    -|       |           |       |-    |     |\n           |     |_-___-___-___-|         |-___-___-___-_|     |\n           |  o  ]              [    0    ]              [  o  |\n           |     ]   o   o   o  [ _______ ]  o   o   o   [     | ----__________\n_____----- |     ]              [ ||||||| ]              [     |\n           |     ]              [ ||||||| ]              [     |\n       _-_-|_____]--------------[_|||||||_]--------------[_____|-_-_\n      ( (__________------------_____________-------------_________) )")
            input("WOAH thats a sick castle let's head inside")
            print("       .-.\n    __ |=|__\n    (_/`-`\_)\n    //\___/\\\n    <>/   \<>\n     \|_._|/\n      <_I_>\n       |||\n      /_|_\\")
            print("oh no it's a knight\n \
                  *KNIGHT*:HALT thou shall not pass without answering my query")
            
            player.choices()
            
            """final health status to determine if they can progress to last stage"""
            print("\n Let's see how your character is doing. "+ player.vitals())
            
            if player.energy() <= 0 :
                print("Your health is too low, you have died")
            else:
                input("Your health is doing okay, time for the final stage")
                
                """final stage ending of game"""
                input("You climb up the stairs of the steepest tower in the castle \n \
                You finally reach the top and reach a door. \nYou open the door slowly........")
                print("                           !     !     !\n(          (    *         |V|   |V|   |V|        )   *   )       (\n )   *      )             | |   | |   | |        (       (   *    )\n(          (           (*******************)    *       *    )    *\n(     (    (           (    *         *    )               )    (\n )   * )    )          (   \|/       \|/   )         *    (      )\n(     (     *          (<<<<<<<<<*>>>>>>>>>)               )    (\n )     )        ((*******************************))       (  *   )\n(     (   *     ((       SURPRISE FOR YOU!!!     ))      * )    (\n ) *   )        ((   *    *   *    *    *    *   ))   *   (      )\n(     (         ((  \|/  \|/ \|/  \|/  \|/  \|/  ))        )    (\n*)     )        ((^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^))       (      )\n(     (   (**********************************************) )  * ( ")
                
                #end of game
                print("~~~~~O MA GAWD IT'S A SURPRISE PARTY JUST FOR YOU ~~~~~")
                input("A party just for YOU ----------> " + player.character+" <------ you look so happy")
                print(" Thanks for playing :) BYEEEEEEE")
        #if player isn't ready for quest then they are booted off
        else:
            print("Get outta here fool")
            
    #if player responds 'no' to being ready (will kick them out of adventure)
    elif answer == 'no' or answer == 'No':
        good = False
        input(" wait What?? you're not ready...then why are you here")
        
    #if player responds with something that isn't 'yes' or 'no' to being ready (will kick them out of adventure)
    else:
        good = False
        input(" You didn't answer my question")

# %%
chat()
# Out:
# Welcome to the adventure! Press enter to move forward in the story.
# What is your name?zy
# Welcome to your story zy!
# Are you ready?yes
# Good Luck Traveler, your quest is about to begin
# Let's set the basics
# Choose your character.
#                      1 --->   ʕ•ᴥ•ʔ
#                      2 --->  (๑•̀ㅂ•́)ﻭ✧
#                      3 --->  (▀̿̿Ĺ̯̿▀̿ ̿)
#                      4 --->  ( ͡° ͜ʖ ͡°) 3
# You have picked --->(▀̿̿Ĺ̯̿▀̿ ̿)
# Let's see how your character is doing. Your health level is at 20
# Okay you seem fine......for now
#                    Winning this game is quite simple
#                    You must answer a riddle but it may not always be easy
# Picture this you're walking when you stumble upon a bridge
#          |  |             | |
#          |  |-------------| |
#          |  |             | |
#          |  |             | |
# ============|===============|===--
# ~~~~~~~~~|  |~~~~~~~~~~~~~| |~~~~~~
# Oh look at that, it's a pig near the bridge
#     _____
# ...
